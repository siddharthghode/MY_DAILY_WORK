# %%
file=open("file.txt","r")
contend=file.read()
print(contend)
file.close()
# Out:
# hii i am siddharth.

# %%
with open("file.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['hii i am siddharth.']

# %%
file=open("file.txt","w")
lines=file.write("hellp wprld")
file.close()
